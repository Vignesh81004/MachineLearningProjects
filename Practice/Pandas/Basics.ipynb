# %%
import pandas as pd

# %%
df = pd.DataFrame([[1,2],[2,4],[3,6]],columns=["A","B"],index=["a","b","c"])

# %%
df
# Out:
#    A  B
# a  1  2
# b  2  4
# c  3  6

# %%
df.head(1)
# Out:
#    A  B
# a  1  2

# %%
df.tail(1)
# Out:
#    A  B
# c  3  6

# %%
df.columns
# Out:
# Index(['A', 'B'], dtype='object')

# %%
df.columns.tolist()
# Out:
# ['A', 'B']

# %%
df.index
# Out:
# Index(['a', 'b', 'c'], dtype='object')

# %%
df.index.tolist()
# Out:
# ['a', 'b', 'c']

# %%
df.shape
# Out:
# (3, 2)

# %%
df.nunique()
# Out:
# A    3
# B    3
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, a to c
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
# dtypes: int64(2)
# memory usage: 72.0+ bytes

# %%
df.describe()
# Out:
#          A    B
# count  3.0  3.0
# mean   2.0  4.0
# std    1.0  2.0
# min    1.0  2.0
# 25%    1.5  3.0
# 50%    2.0  4.0
# 75%    2.5  5.0
# max    3.0  6.0

# %% [markdown]
# # Sample Dataset

# %%
df = pd.read_csv("Coffee.csv")

# %%
df
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
df.head()
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35

# %%
df.describe()
# Out:
#        Units Sold
# count   14.000000
# mean    32.857143
# std      9.346798
# min     15.000000
# 25%     26.250000
# 50%     35.000000
# 75%     38.750000
# max     45.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 0 to 13
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Day          14 non-null     object
#  1   Coffee Type  14 non-null     object
#  2   Units Sold   14 non-null     int64
# dtypes: int64(1), object(2)
# memory usage: 468.0+ bytes

# %%
df.nunique()
# Out:
# Day            7
# Coffee Type    2
# Units Sold     7
# dtype: int64

# %%
df[df["Coffee Type"] == "Espresso"]
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 2     Tuesday    Espresso          30
# 4   Wednesday    Espresso          35
# 6    Thursday    Espresso          40
# 8      Friday    Espresso          45
# 10   Saturday    Espresso          45
# 12     Sunday    Espresso          45

# %%
df[df["Coffee Type"] == "Espresso"].describe()
# Out:
#        Units Sold
# count    7.000000
# mean    37.857143
# std      8.091736
# min     25.000000
# 25%     32.500000
# 50%     40.000000
# 75%     45.000000
# max     45.000000

# %%
df.loc[0]
# Out:
# Day              Monday
# Coffee Type    Espresso
# Units Sold           25
# Name: 0, dtype: object

# %%
df.loc[[0,1],["Day","Units Sold"]]
# Out:
#       Day  Units Sold
# 0  Monday          25
# 1  Monday          15

# %%
df.loc[2:10,["Day","Units Sold"]]
# Out:
#           Day  Units Sold
# 2     Tuesday          30
# 3     Tuesday          20
# 4   Wednesday          35
# 5   Wednesday          25
# 6    Thursday          40
# 7    Thursday          30
# 8      Friday          45
# 9      Friday          35
# 10   Saturday          45

# %%
test = df.loc[:5]

# %%
test
# Out:
#          Day Coffee Type  Units Sold
# 0     Monday    Espresso          25
# 1     Monday       Latte          15
# 2    Tuesday    Espresso          30
# 3    Tuesday       Latte          20
# 4  Wednesday    Espresso          35
# 5  Wednesday       Latte          25

# %%
test.index = ["a","b","c","d","e","f"]

# %%
test
# Out:
#          Day Coffee Type  Units Sold
# a     Monday    Espresso          25
# b     Monday       Latte          15
# c    Tuesday    Espresso          30
# d    Tuesday       Latte          20
# e  Wednesday    Espresso          35
# f  Wednesday       Latte          25

# %%
test.loc["c":,["Day","Units Sold"]]
# Out:
#          Day  Units Sold
# c    Tuesday          30
# d    Tuesday          20
# e  Wednesday          35
# f  Wednesday          25

# %%
test.iloc[2:5,[0,1,2]] # We Use index of rows and colums
# Out:
#          Day Coffee Type  Units Sold
# c    Tuesday    Espresso          30
# d    Tuesday       Latte          20
# e  Wednesday    Espresso          35

# %%
df
# Out:
#           Day Coffee Type  Units Sold
# 0      Monday    Espresso          25
# 1      Monday       Latte          15
# 2     Tuesday    Espresso          30
# 3     Tuesday       Latte          20
# 4   Wednesday    Espresso          35
# 5   Wednesday       Latte          25
# 6    Thursday    Espresso          40
# 7    Thursday       Latte          30
# 8      Friday    Espresso          45
# 9      Friday       Latte          35
# 10   Saturday    Espresso          45
# 11   Saturday       Latte          35
# 12     Sunday    Espresso          45
# 13     Sunday       Latte          35

# %%
df[df.iloc[:,1] == "Latte"]
# Out:
#           Day Coffee Type  Units Sold
# 1      Monday       Latte          15
# 3     Tuesday       Latte          20
# 5   Wednesday       Latte          25
# 7    Thursday       Latte          30
# 9      Friday       Latte          35
# 11   Saturday       Latte          35
# 13     Sunday       Latte          35

# %%
test
# Out:
#          Day Coffee Type  Units Sold
# a     Monday    Espresso          25
# b     Monday       Latte          15
# c    Tuesday    Espresso          30
# d    Tuesday       Latte          20
# e  Wednesday    Espresso          35
# f  Wednesday       Latte          25

# %%
test.iloc[1,2]
# Out:
# 15

# %%
test.iloc[1,2] = 100

# %%
test
# Out:
#          Day Coffee Type  Units Sold
# a     Monday    Espresso          25
# b     Monday       Latte         100
# c    Tuesday    Espresso          30
# d    Tuesday       Latte          20
# e  Wednesday    Espresso          35
# f  Wednesday       Latte          25

# %%
test.sort_values("Units Sold")
# Out:
#          Day Coffee Type  Units Sold
# d    Tuesday       Latte          20
# a     Monday    Espresso          25
# f  Wednesday       Latte          25
# c    Tuesday    Espresso          30
# e  Wednesday    Espresso          35
# b     Monday       Latte         100

# %%
test.sort_values("Units Sold",ascending=0)
# Out:
#          Day Coffee Type  Units Sold
# b     Monday       Latte         100
# e  Wednesday    Espresso          35
# c    Tuesday    Espresso          30
# a     Monday    Espresso          25
# f  Wednesday       Latte          25
# d    Tuesday       Latte          20

# %% [markdown]
# # Olympic Data set

# %%
df = pd.read_csv("https://raw.githubusercontent.com/KeithGalli/complete-pandas-tutorial/refs/heads/master/data/bios.csv")

# %%
df
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 2                3           Jean Borotra  1898-08-13         Biarritz
# 3                4        Jacques Brugnon  1895-05-11      Paris VIIIe
# 4                5           Albert Canet  1878-04-17       Wandsworth
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#                  born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 145500 entries, 0 to 145499
# Data columns (total 10 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   athlete_id    145500 non-null  int64
#  1   name          145500 non-null  object
#  2   born_date     143693 non-null  object
#  3   born_city     110908 non-null  object
#  4   born_region   110908 non-null  object
#  5   born_country  110908 non-null  object
#  6   NOC           145499 non-null  object
#  7   height_cm     106651 non-null  float64
#  8   weight_kg     102070 non-null  float64
#  9   died_date     33940 non-null   object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 11.1+ MB

# %%
df.describe()
# Out:
#           athlete_id      height_cm      weight_kg
# count  145500.000000  106651.000000  102070.000000
# mean    73686.188955     176.333724      71.890996
# std     42868.960158      10.380282      14.465540
# min         1.000000     127.000000      25.000000
# 25%     36663.750000     170.000000      62.000000
# 50%     73302.500000     176.000000      70.000000
# 75%    110306.250000     183.000000      80.000000
# max    149814.000000     226.000000     198.000000

# %%
df.isnull()
# Out:
#         athlete_id   name  born_date  born_city  born_region  born_country  \
# 0            False  False      False      False        False         False
# 1            False  False      False      False        False         False
# 2            False  False      False      False        False         False
# 3            False  False      False      False        False         False
# 4            False  False      False      False        False         False
# ...            ...    ...        ...        ...          ...           ...
# 145495       False  False      False      False        False         False
# 145496       False  False      False      False        False         False
# 145497       False  False      False      False        False         False
# 145498       False  False      False      False        False         False
# 145499       False  False      False      False        False         False
#
#           NOC  height_cm  weight_kg  died_date
# ...

# %%
df.isnull().any(axis=0)
# Out:
# athlete_id      False
# name            False
# born_date        True
# born_city        True
# born_region      True
# born_country     True
# NOC              True
# height_cm        True
# weight_kg        True
# died_date        True
# dtype: bool

# %%
df.isnull().any(axis=1)
# Out:
# 0          True
# 1          True
# 2         False
# 3         False
# 4          True
#           ...
# 145495     True
# 145496     True
# 145497     True
# 145498     True
# 145499     True
# Length: 145500, dtype: bool

# %%
df[df.isnull().any(axis=1)].
# Out:
#         athlete_id                   name   born_date        born_city  \
# 0                1  Jean-François Blanchy  1886-12-12         Bordeaux
# 1                2         Arnaud Boetsch  1969-04-01           Meulan
# 4                5           Albert Canet  1878-04-17       Wandsworth
# 5                6      Nicolas Chatelain  1970-01-13           Amiens
# 6                7          Patrick Chila  1969-11-27      Ris-Orangis
# ...            ...                    ...         ...              ...
# 145495      149222      Polina Luchnikova  2002-01-30            Serov
# 145496      149223    Valeriya Merkusheva  1999-09-20  Moskva (Moscow)
# 145497      149224        Yuliya Smirnova  1998-05-08           Kotlas
# 145498      149225         André Foussard  1899-05-19            Niort
# 145499      149814          Bill Phillips  1913-07-15     Dulwich Hill
#
#             born_region born_country        NOC  height_cm  weight_kg  \
# ...

# %%
df.isnull().sum()
# Out:
# athlete_id           0
# name                 0
# born_date         1807
# born_city        34592
# born_region      34592
# born_country     34592
# NOC                  1
# height_cm        38849
# weight_kg        43430
# died_date       111560
# dtype: int64
